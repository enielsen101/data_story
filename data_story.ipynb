# %%
import pandas as pd

# %%
## import the csv
df = pd.read_csv("data_raw/NLRB_filings.csv")

# %%
## Get info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53784 entries, 0 to 53783
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      53784 non-null  object
#  1   Case Number               53784 non-null  object
#  2   City                      53780 non-null  object
#  3   States & Territories      53784 non-null  object
#  4   Date Filed                53784 non-null  object
#  5   Region Assigned           53784 non-null  object
#  6   Status                    53784 non-null  object
#  7   Date Closed               52892 non-null  object
#  8   Reason Closed             52848 non-null  object
#  9   No. of Eligible Voters    30392 non-null  float64
#  10  No. of Employees          53380 non-null  float64
#  11  Certified Representative  20648 non-null  object
#  12  Unit Sought               50162 non-null  object
# dtypes: float64(2), object(11)
# ...

# %%
## Get beginning rows
df.head()
# Out:
#                                                 Name   Case Number  \
# 0          Martignetti Companies of Connecticut, LLC  01-RM-363455
# 1                        BUCKEYE STATE SEEDING, INC.  09-RC-363492
# 2                     Westerly Ambulance Corps, Inc.  01-RC-363485
# 3                         Oldcastle BuildingEnvelope  04-RC-363490
# 4  Southern Home Care Services, Inc. d/b/a/ All W...  19-RM-363513
#
#            City States & Territories  Date Filed  \
# 0     Stratford                   CT  04/10/2025
# 1  Williamsport                   OH  04/10/2025
# 2      Westerly                   RI  04/10/2025
# 3    Moorestown                   NJ  04/10/2025
# 4      Missoula                   MT  04/10/2025
#
#                          Region Assigned          Status Date Closed  \
# 0       Region 01, Boston, Massachusetts            Open         NaN
# 1            Region 09, Cincinnati, Ohio            Open         NaN
# ...

# %%
## Get sample
df.sample()
# Out:
#                        Name   Case Number       City States & Territories  \
# 49964  Image City Interiors  03-RC-011636  Rochester                   NY
#
#        Date Filed               Region Assigned  Status Date Closed  \
# 49964  08/09/2005  Region 03, Buffalo, New York  Closed  08/19/2005
#
#                  Reason Closed  No. of Eligible Voters  No. of Employees  \
# 49964  Withdrawal Non-adjusted                     NaN               4.0
#
#       Certified Representative  \
# 49964                      NaN
#
#                                              Unit Sought
# 49964  All Carpenter, carpenter helpers and apprentic...

# %%
# Filter rows by RC to get only union filing petitions
df[df["Case Number"].str.contains("-RC-")]
# Out:
#                                              Name   Case Number  \
# 1                     BUCKEYE STATE SEEDING, INC.  09-RC-363492
# 2                  Westerly Ambulance Corps, Inc.  01-RC-363485
# 3                      Oldcastle BuildingEnvelope  04-RC-363490
# 5                   The Davey Tree Expert Company  15-RC-363477
# 6                              Uptown Care Center  13-RC-363519
# ...                                           ...           ...
# 53779      Laidlaw Waste Management Systems, Inc.  07-RC-019141
# 53780                Daniel F. Allen & Co.,  Inc.  29-RC-006979
# 53781              New Brighton Manor Care Center  29-RC-006560
# 53782  Northwind Maintenance & Painting Co., Inc.  29-RC-006343
# 53783                   B. R. B. Iron Works, Inc.  29-RC-006167
#
#                 City States & Territories  Date Filed  \
# 1       Williamsport                   OH  04/10/2025
# 2           Westerly                   RI  04/10/2025
# ...

# %%
## Get info for filtered dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40370 entries, 1 to 53783
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      40370 non-null  object
#  1   Case Number               40370 non-null  object
#  2   City                      40367 non-null  object
#  3   States & Territories      40370 non-null  object
#  4   Date Filed                40370 non-null  datetime64[ns]
#  5   Region Assigned           40370 non-null  object
#  6   Status                    40370 non-null  object
#  7   Date Closed               39770 non-null  object
#  8   Reason Closed             39758 non-null  object
#  9   No. of Eligible Voters    25792 non-null  float64
#  10  No. of Employees          40179 non-null  float64
#  11  Certified Representative  18587 non-null  object
#  12  Unit Sought               37984 non-null  object
# ...

# %%
## Get info from filtered dataset
df.tail()
# Out:
#                                              Name   Case Number  \
# 53779      Laidlaw Waste Management Systems, Inc.  07-RC-019141
# 53780                Daniel F. Allen & Co.,  Inc.  29-RC-006979
# 53781              New Brighton Manor Care Center  29-RC-006560
# 53782  Northwind Maintenance & Painting Co., Inc.  29-RC-006343
# 53783                   B. R. B. Iron Works, Inc.  29-RC-006167
#
#                 City States & Territories Date Filed  \
# 53779       Columbus                   OH 1989-11-17
# 53780     Hicksville                   NY 1988-04-15
# 53781  STATEN ISLAND                   NY 1986-04-21
# 53782       New York                   NY 1985-02-19
# 53783         CORONA                   NY 1984-05-07
#
#                      Region Assigned  Status Date Closed  \
# 53779   Region 07, Detroit, Michigan  Closed  06/11/2008
# 53780  Region 29, Brooklyn, New York  Closed  01/08/2008
# 53781  Region 29, Brooklyn, New York  Closed  07/11/2007
# ...

# %%
## Filter df by date date filed
df["Date Filed"] = pd.to_datetime(df["Date Filed"], errors="coerce")

# %%
## Filter df by FY 2021 and 2024
df_fy_filtered = df.query(
    "(@pd.to_datetime('2020-10-01') <= `Date Filed` <= @pd.to_datetime('2021-09-30')) or \
     (@pd.to_datetime('2023-10-01') <= `Date Filed` <= @pd.to_datetime('2024-09-30'))"
)

# %%
## Get info on new dataset - #s do not match NLRB reports, so something went wrong
df_fy_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3640 entries, 1438 to 11460
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      3640 non-null   object
#  1   Case Number               3640 non-null   object
#  2   City                      3640 non-null   object
#  3   States & Territories      3640 non-null   object
#  4   Date Filed                3640 non-null   datetime64[ns]
#  5   Region Assigned           3640 non-null   object
#  6   Status                    3640 non-null   object
#  7   Date Closed               3471 non-null   object
#  8   Reason Closed             3471 non-null   object
#  9   No. of Eligible Voters    2695 non-null   float64
#  10  No. of Employees          3640 non-null   float64
#  11  Certified Representative  2132 non-null   object
#  12  Unit Sought               3576 non-null   object
# ...

# %%
## Put 2021 and 2024 into dataframes
df_2021 = df[df["Date Filed"].dt.year == 2021]
df_2024 = df[df["Date Filed"].dt.year == 2024]

# %%
## Get info on df_2021
df_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1381 entries, 9348 to 11098
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      1381 non-null   object
#  1   Case Number               1381 non-null   object
#  2   City                      1381 non-null   object
#  3   States & Territories      1381 non-null   object
#  4   Date Filed                1381 non-null   datetime64[ns]
#  5   Region Assigned           1381 non-null   object
#  6   Status                    1381 non-null   object
#  7   Date Closed               1374 non-null   object
#  8   Reason Closed             1374 non-null   object
#  9   No. of Eligible Voters    1028 non-null   float64
#  10  No. of Employees          1381 non-null   float64
#  11  Certified Representative  804 non-null    object
#  12  Unit Sought               1350 non-null   object
# ...

# %%
## Get info on 2024 - this is also not correct. Something wrong with date formatting?
df_2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2361 entries, 750 to 3971
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      2361 non-null   object
#  1   Case Number               2361 non-null   object
#  2   City                      2361 non-null   object
#  3   States & Territories      2361 non-null   object
#  4   Date Filed                2361 non-null   datetime64[ns]
#  5   Region Assigned           2361 non-null   object
#  6   Status                    2361 non-null   object
#  7   Date Closed               2170 non-null   object
#  8   Reason Closed             2170 non-null   object
#  9   No. of Eligible Voters    1760 non-null   float64
#  10  No. of Employees          2361 non-null   float64
#  11  Certified Representative  1419 non-null   object
#  12  Unit Sought               2329 non-null   object
# ...

# %%
df_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1381 entries, 9348 to 11098
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      1381 non-null   object
#  1   Case Number               1381 non-null   object
#  2   City                      1381 non-null   object
#  3   States & Territories      1381 non-null   object
#  4   Date Filed                1381 non-null   datetime64[ns]
#  5   Region Assigned           1381 non-null   object
#  6   Status                    1381 non-null   object
#  7   Date Closed               1374 non-null   object
#  8   Reason Closed             1374 non-null   object
#  9   No. of Eligible Voters    1028 non-null   float64
#  10  No. of Employees          1381 non-null   float64
#  11  Certified Representative  804 non-null    object
#  12  Unit Sought               1350 non-null   object
# ...

# %%
df_2021.head()
# Out:
#                                                    Name   Case Number  \
# 9348  CoreCivic of Tennessee, LLC d/b/a Central Ariz...  28-RC-288330
# 9351                              Starbucks Corporation  27-RC-288318
# 9352  Central Network Retail Group, LLC d/b/a Fratta...  18-RC-288324
# 9353                       Riverstreet Center Opco, LLC  04-RC-288206
# 9355                         C&W Facility Services Inc.  01-RC-288234
#
#               City States & Territories Date Filed  \
# 9348      Florence                   AZ 2021-12-30
# 9351    Louisville                   CO 2021-12-30
# 9352  Circle Pines                   MN 2021-12-30
# 9353  Wilkes-Barre                   PA 2021-12-29
# 9355   Marlborough                   MA 2021-12-29
#
#                             Region Assigned  Status Date Closed  \
# 9348            Region 28, Phoenix, Arizona  Closed  03/31/2022
# 9351            Region 27, Denver, Colorado  Closed  05/23/2022
# ...
